# %% [markdown]
# # Буркіна-Фасо

# %% [markdown]
# **[Буркіна́-Фасо́](https://uk.wikipedia.org/wiki/%D0%91%D1%83%D1%80%D0%BA%D1%96%D0%BD%D0%B0-%D0%A4%D0%B0%D1%81%D0%BE)** — незалежна держава у Західній Африці. **Столиця — [Уагадугу](https://uk.wikipedia.org/wiki/%D0%A3%D0%B0%D0%B3%D0%B0%D0%B4%D1%83%D0%B3%D1%83).**

# %% [markdown]
# ### Населення

# %% [markdown]
# *Населення держави у 2006 році становило 13,9 млн осіб. У 1950 році — 3,1 млн, у 1970 — 5,4 млн, у 1980 — 6,9 млн осіб. Густота населення: 44,7 осіб/км² (121-е місце в світі). Згідно зі статистичними даними за 2006 рік народжуваність складала 45,6 ‰ (4-е місце в світі); смертність — 15,6 ‰; природний приріст — 30 ‰ (11-е місце в світі).*

# %% [markdown]
# *Вікова піраміда населення виглядає наступним чином (станом на 2006 рік):*

# %% [markdown]
# - діти віком до 14 років — 47 % (3,3 млн чоловіків, 3,2 млн жінок);
# - дорослі (15-64 років) — 51 % (3,5 млн чоловіків, 3,5 млн жінок);
# - особи похилого віку (65 років і старіші) — 2 % (0,14 млн чоловіків, 0,21 млн жінок).

# %% [markdown]
# ### Географія

# %% [markdown]
# Держава знаходиться в Західній Африці. Територія країни простяглася із заходу на схід на 845 км, а з півночі на південь на 645 км. На північному заході межує з Малі (спільний кордон — 1325 км); на північному сході — з Нігером (622 км); на півдні — з Беніном (386 км), Того (131 км), Ганою (602 км), Кот-д'Івуаром (545 км). Країна не має виходу до моря.
# **Територія — 273 187 км²**

# %% [markdown]
# ### Політичний устрій

# %% [markdown]
# - Глава держави - президент, який обирається загальним голосуванням (з 29 грудня 2015 року президент країни - Рок Марк Крістіан Каборе).
# - Глава уряду - прем'єр-міністр, який призначається президентом (з 6 січня 2016 року - Поль Каба Тіеба).
# - Парламент двопалатний - Національна Асамблея (111 депутатів обираються загальним голосуванням на 5-річний термін) і Палати Представників (Chambre des Representants) - 178 місць (члени обираються на термін в 3 роки).

# %% [markdown]
# ### Державний устрій

# %% [markdown]
# |№	|Область		    |Область (Фр.)	  |Адміністративний центр |Кіл-ть провінцій |Площа, км² |Населення (2006), чол. |Щільність, чол/км² |
# |---|-------------------|-----------------|-----------------------|-----------------|-----------|-----------------------|-------------------|
# |1	|Букле-ду-Мухун	    |Boucle du Mouhoun|Дедугу				  |6				|34 479		|1 434 847				|41,62				|
# |2	|Каскади		    |Cascades		  |Банфора				  |2				|16 663		|524 956				|31,50				|
# |3	|Центральна		    |Centre			  |Уагадугу				  |1				|2 805		|1 523 980				|543,31				|
# |4	|Східно-Центральна  |Centre-Est		  |Тенкодого			  |3				|14 852		|1 132 023				|76,22				|
# |5	|Північно-Центральна|Centre-Nord	  |Кая					  |3				|19 508		|1 203 073				|61,67				|
# |6	|Західно-Центральна	|Centre-Ouest	  |Кудугу				  |4				|21 853		|1 183 473				|54,16				|
# |7	|Південно-Центральна|Centre-Sud		  |Манга				  |3				|11 313		|638 379				|56,43				|
# |8	|Східна				|Est			  |Фада-Нґурма			  |5				|46 256		|1 209 399				|26,15				|
# |9	|Верхні Басейни		|Hauts-Bassins	  |Бобо-Діуласо			  |3				|26 606		|1 410 284				|53,01				|
# |10	|Північна			|Nord			  |Уахігуя				  |4				|17 601		|1 182 770				|67,20				|
# |11	|Центральне Плато	|Plateau-Central  |Зініарі				  |3				|8 545		|647 516				|75,78				|
# |12	|Сахель				|Sahel			  |Дорі					  |4				|36 130		|808 928				|22,39				|
# |13	|Південно-Західна	|Sud-Ouest		  |Гава					  |4				|16 576		|623 056				|37,59				|
# |	|Всего				|				  |						  |45				|273 187	|13 522 684				|49,50				|

# %% [markdown]
# ### Визначні пам'ятки

# %% [markdown]
# #### Собор Уагудагу

# %% [markdown]
# ![Church](Pictures/church.jpg)
#
# Собор Уагадугу це католицька церква в однойменному місті, яка носить назву церкви Непорочного Зачаття Пресвятої Діви Марії. У Західній і Південній Африці цей кафедральний собор католицької єпархії вважається одним з найбільших. Його побудували в 1936 році з використанням традиційного для регіону сирцевої цегли. Масштабне будова виконано в європейському романському стилі з деякими елементами західно-африканської архітектури. Форма базиліки, в якій виконані два основних рівня будівлі, нагадує садибу або особняк. Чудові елементи будівлі - дві вежі різної висоти, які начебто не добудували і позбавили шпилів.

# %% [markdown]
# #### Національний музей музики Буркіна-Фасо

# %% [markdown]
# ![Museum](Pictures/Museum.jpg)
#
# Національний музей музики Уагадугу розташований в двоповерховій будівлі на проспекті капітана Томаса Санкари. Раніше будова займала Асоціація з розвитку африканської архітектури і містобудування, а потім його реконструювали під музей. Виконано будівлю музею в судано-сахельского стилі з куполоподібними дахами.
#
# Першу колекцію в музеї представили в 1998 році і згодом вона постійно розширювалася. Тут представлені експонати всіх сімейств музичних інструментів, включаючи Аерофон, мембранофони, ідіофони і хордофони.

# %% [markdown]
# #### Національний парк Арлі

# %% [markdown]
# ![Park](Pictures/Park.jpg)
#
# На 76 тисячах гектарів землі на південному сході Буркіна-Фасо розташувався Національний парк Арлі. Переважає тут трав'яниста і лісова савана. Парк розташований на висотах від 100 до 500 метрів над рівнем моря. Тваринний світ його досить різноманітний і вже точно екзотичний. У парку проживає не менше 200 слонів, не менше 100 левів, буйволи, леопарди, бегемоти і бородавочники. Також Арлі це будинок для крокодилів, пітонів, нільських варанів, безлічі мавп і антилоп різних видів.

# %% [markdown]
# #### Біосферний резерват Мар-оз-Іппопотам

# %% [markdown]
# ![Bio](Pictures/Bio.jpg)
#
# Біосферний резерват Мар-оз-Іппопотам або «озеро гіпопотамів» розташований на південно-заході Буркіна-Фасо, в 50 кілометрах на північ від Бобо-Діуласо. У 1977 році його включили до Всесвітньої мережі резерватів. Озеро отримало свою назву не випадково, це улюблене місце проживання гіпопотамів, яких тут налічується більше 100 особин. Також тут мешкає 250 видів птахів, з яких багато водоплавні. Місцевість навколо озера складають водоохоронні ліси, які потім переходять в савану. Місцеві жителі вважають озеро священним місцем.

# - 2006 — Като Като / Kato Kato

# %% [markdown]
# #### Моріс Ямеого

# %% [markdown]
# ![President](Pictures/President.jpg)
#
# [Моріс Ямеого](https://uk.wikipedia.org/wiki/%D0%9C%D0%BE%D1%80%D1%96%D1%81_%D0%AF%D0%BC%D0%B5%D0%BE%D0%B3%D0%BE) (фр. Maurice Yaméogo, 31 грудня 1921 — 9 вересня 1993) — перший президент (з 1960 до 1966 року) Верхньої Вольти (нині Буркіна-Фасо). Моріс Ямеого був представником народності мосі, тобто належав до найбільшої етнічної групи країни. Після закінчення місіонерської школи навчався в католицькій семінарії, маючи намір стати священиком. Однак, познайомившись із Фелісіте Загре (майбутньою своєю першою дружиною), Ямеого залишив духовну кар'єру та вступив на адміністративну службу.
#
# З 1946 року Ямеого — член парламенту французьких Заморських територій, з 1948 — член Ради [Французької Західної Африки](https://uk.wikipedia.org/wiki/%D0%A4%D1%80%D0%B0%D0%BD%D1%86%D1%83%D0%B7%D1%8C%D0%BA%D0%B0_%D0%97%D0%B0%D1%85%D1%96%D0%B4%D0%BD%D0%B0_%D0%90%D1%84%D1%80%D0%B8%D0%BA%D0%B0). З 1954 очолював християнську профспілку CTFC у Верхній Вольті. 1957 року Ямеого заснував партію ***Вольтійський демократичний рух***. На виборах в колонії того ж року партія здобувши у місцевому парламенті 26 місць із 70, увійшла до урядової коаліції і Ямеого став міністром сільського господарства в уряді колоніальної автономії.
#
# Наприкінці 1957 року після розвалу коаліції, Ямеого перейшов до лав найбільшої партії Верхньої Вольти — ***Африканські збори за демократію***. 1958 року він став міністром внутрішніх справ, потім — прем'єр-міністром. Підтримував на цій посаді запланований вступ ***Верхньої Вольти*** до Малійської Федерації. 1964 року президент розлучився зі своєю першою дружиною та знову одружився — з колишньою ***Міс Верхня Вольта***.
#
# 9 жовтня 1965 року Ямеого знову був обраний президентом Верхньої Вольти, набравши 99,9% голосів виборців. Після хвилювань та генерального страйку, що відбувся 3 січня 1966 року, Ямеого був змушений піти у відставку і президентом став генерал Сангуле Ламізана. До 1968 року Ямеого перебував під арештом. Знову був заарештований 1983 після приходу до влади Томаса Санкари, звільнений 1985 року, після чого емігрував до Кот-д'Івуару. Повернувся на батьківщину тільки 1990 року.

# %% [markdown]
# ### Прапор країни

# %% [markdown]
# ![flag](https://upload.wikimedia.org/wikipedia/commons/archive/3/31/20070107031032%21Flag_of_Burkina_Faso.svg)

# %% [markdown]
# ## Завдання 5
#
# **Реалізація алгоритму Евкліда, для знаходження найбільшого спільного дільника.**

# %%
def check(first, second):
    list_for = []
    if first > second:
        list_for.append(first)
        list_for.append(second)
    else:
        list_for.append(second)
        list_for.append(first)
    return list_for


def evklid(first_number, second_number):
    result = []
    list_with_numbers = check(first_number, second_number)
    iterator = 2
    while first_number != 0:
        first_number = list_with_numbers[iterator - 2] % list_with_numbers[iterator - 1]
        list_with_numbers.append(first_number)
        result.append(first_number)
        iterator = iterator + 1
    return max(result)

# %%
print(evklid(12, 54))
# Out:
# 6
